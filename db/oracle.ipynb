# %% [markdown]
# ### oracle 서버와 파이썬 연동
# - uv pip install oracledb

# %%
import oracledb
from dotenv import load_dotenv  # python-dotenv
import os

# %%
# .env 파일 읽어오기
load_dotenv()

# 오라클 비밀번호 가져오기
password = os.getenv("ORACLE_PASSWORD")

# %%
conn = oracledb.connect(user="python_user",password=password,dsn="localhost/xe")
cursor = conn.cursor()

cursor.execute("select * from post")

for row in cursor.fetchall():
    print(row)

conn.close()

# %%
sql = "insert into hanbit_member(member_id,name,password) values(:1, :2, :3)"
# sql = "insert into hanbit_member(member_id,name,password) values(:member_id,:name,:password)"

with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:
        cursor.execute(sql,('hong123','홍길동','hong123'))
        conn.commit()

# %%
with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:
        cursor.execute("select * from hanbit_member")

        for row in cursor.fetchall():
            print(row)
# Out:
# ('hong123', '홍길동', 'hong123', None, 'REGULAR', 0)
# ('kim123', '김길동', 'kim123', None, 'REGULAR', 0)
# ('choi123', '조미연', 'choi123', None, 'REGULAR', 0)

# %%
sql = "insert into hanbit_member(member_id,name,password) values(:member_id,:name,:password)"

with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:
        cursor.execute(sql,('kim123','김길동','kim123'))
        conn.commit()

# %%
sql = "insert into hanbit_member(member_id,name,password) values(:member_id,:name,:password)"

with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:

        data = {
            "member_id":"choi123",
            "name":"조미연",
            "password":"choi123"
        }

        cursor.execute(sql,data)
        conn.commit()

# %%
sql = "insert into category(category_id,category_name) values(:1, :2)"

with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:
        cursor.execute(sql,(1101,'경제/경영'))
        conn.commit()

# %%
with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:
        cursor.execute("select * from category")
        for row in cursor.fetchall():
            print(row)
# Out:
# (1101, '경제/경영')
# (1102, '요리')
# (1103, '예술')
# (1104, '자기계발')

# %%
sql = "insert into category(category_id,category_name) values(:1, :2)"

data = [
    [1102,'요리'],
    [1103,'예술'],
    [1104,'사회']
]

with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:
        cursor.executemany(sql,data)
        conn.commit()

# %%
# 사회 => 자기계발

sql = "update category set category_name = :1 where category_id = :2"

with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:
        cursor.execute(sql,("자기계발",1104))
        conn.commit()

# %%
sql = "delete from category where category_id = :1"

with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:
        cursor.execute(sql,(1103,))
        conn.commit()

# %%
from faker import Faker

fake = Faker(locale="ko_KR")
Faker.seed(4321)

print(fake.name())
print(fake.email())
print(fake.address())
print(fake.ssn())
print(fake.phone_number())
# Out:
# 이도윤
# sunoggim@example.net
# 대구광역시 영등포구 서초중앙거리 238-52
# 670227-2018273
# 070-4938-5639

# %%
from faker.providers import internet

fake.add_provider(internet)

for i in range(10):
    print(fake.ipv4_private())
# Out:
# 192.168.134.136
# 192.168.107.240
# 192.168.112.114
# 192.168.151.178
# 10.179.78.168
# 172.18.48.9
# 172.22.63.107
# 10.33.13.83
# 192.168.231.224
# 192.168.222.129

# %%
fake.date_of_birth(minimum_age=20, maximum_age=30)
fake.date_of_birth(minimum_age=20, maximum_age=30).strftime("%Y-%m-%d")
# Out:
# '2003-11-03'

# %%
fake.date_time_between(start_date="-3y",end_date="now")
# Out:
# datetime.datetime(2026, 1, 4, 7, 33, 4)

# %%
# maru_member 50명 임의의 데이터를 이용해 삽입
# name,birth,phone,joined_at

# 50명의 데이터를 리스트에 추가

data = []

for _ in range(50):
    # name
    name = fake.name()
    birth = fake.date_of_birth(minimum_age=20, maximum_age=70).strftime("%Y-%m-%d")
    phone = fake.phone_number()
    joined_at = fake.date_time_between(start_date="-2y",end_date="now")
    data.append([name,birth,phone,joined_at])

print(data)

# insert
# Out:
# [['이중수', '1979-06-18', '061-611-5493', datetime.datetime(2025, 1, 17, 5, 57, 9)], ['임정호', '1982-07-09', '018-756-1478', datetime.datetime(2024, 11, 1, 18, 4, 30)], ['류채원', '1976-08-20', '031-034-1890', datetime.datetime(2025, 6, 21, 21, 2, 30)], ['이미숙', '1968-08-23', '017-841-1987', datetime.datetime(2025, 7, 12, 17, 57, 41)], ['최하은', '1962-07-02', '042-904-6438', datetime.datetime(2024, 12, 3, 11, 23, 21)], ['이하윤', '1978-01-11', '017-035-5839', datetime.datetime(2024, 9, 8, 20, 9, 58)], ['이혜진', '1957-03-31', '017-103-3358', datetime.datetime(2024, 11, 13, 4, 43, 45)], ['권순옥', '2002-06-10', '044-299-1312', datetime.datetime(2024, 11, 8, 2, 29, 34)], ['안상철', '2000-06-26', '052-126-7287', datetime.datetime(2024, 10, 24, 10, 58, 27)], ['김은경', '2001-10-19', '043-812-8151', datetime.datetime(2026, 3, 9, 1, 38, 26)], ['김미경', '1974-06-19', '02-3856-5044', datetime.datetime(2024, 10, 20, 4, 2, 37)], ['김영호', '1977-01-26', '019-635-6403', datetime.datetime(2024, 9, 6, 4, 28, 29)], ['이아름', '1958-08-18', '055-626-5837', datetime.datetime(2026, 4, 14, 0, 57, 49)], ['김서영', '1991-06-21', '055-711-4329', datetime.datetime(2024, 9, 7, 14, 31)], ['윤유진', '1970-11-15', '031-862-6304', datetime.datetime(2025, 3, 21, 3, 49, 1)], ['배경희', '2004-02-03', '063-524-9412', datetime.datetime(2025, 11, 23, 15, 46, 28)], ['박은영', '2002-07-13', '018-441-2107', datetime.datetime(2026, 4, 2, 18, 38, 9)], ['김영식', '2003-10-18', '062-022-4893', datetime.datetime(2024, 11, 17, 22, 43, 26)], ['양순옥', '1989-10-13', '042-597-2680', datetime.datetime(2025, 10, 4, 9, 34, 28)], ['김준혁', '1980-05-11', '017-885-2866', datetime.datetime(2024, 9, 19, 7, 48, 12)], ['진정호', '1968-11-16', '032-799-8159', datetime.datetime(2025, 4, 28, 2, 39, 49)], ['김성민', '1997-02-19', '031-419-7287', datetime.datetime(2026, 2, 6, 6, 35, 23)], ['김정호', '1986-01-16', '031-412-7115', datetime.datetime(2025, 1, 29, 1, 5, 44)], ['이정남', '1997-08-28', '042-093-8561', datetime.datetime(2025, 4, 16, 13, 35, 9)], ['김정식', '1964-09-11', '063-713-6913', datetime.datetime(2025, 2, 26, 1, 46, 5)], ['이종수', '1980-08-22', '02-9641-2299', datetime.datetime(2026, 5, 20, 22, 50, 1)], ['황혜진', '1964-06-17', '02-4171-6672', datetime.datetime(2025, 10, 9, 10, 30, 14)], ['김정희', '1986-01-03', '070-6361-9774', datetime.datetime(2025, 1, 17, 13, 10, 26)], ['정영길', '2002-10-07', '041-064-5622', datetime.datetime(2024, 9, 24, 3, 45, 36)], ['임선영', '1975-09-29', '053-325-4787', datetime.datetime(2025, 3, 5, 1, 21, 33)], ['김서연', '1959-09-08', '017-450-0681', datetime.datetime(2024, 9, 24, 3, 17, 29)], ['김미경', '1964-02-09', '019-181-4446', datetime.datetime(2025, 4, 6, 11, 49, 48)], ['김민서', '1966-09-29', '042-866-9580', datetime.datetime(2026, 1, 24, 18, 52, 40)], ['안영호', '1976-09-17', '011-970-4109', datetime.datetime(2025, 10, 29, 18, 16, 40)], ['박주원', '1966-03-31', '019-074-8341', datetime.datetime(2024, 11, 6, 13, 1, 24)], ['김상현', '1992-03-28', '043-693-8273', datetime.datetime(2025, 12, 18, 22, 11, 9)], ['이우진', '1990-06-22', '017-251-2991', datetime.datetime(2025, 2, 1, 19, 0, 1)], ['이건우', '1955-08-23', '054-163-7326', datetime.datetime(2026, 8, 17, 19, 16, 15)], ['장예지', '2005-11-11', '061-733-3864', datetime.datetime(2025, 1, 31, 13, 53, 42)], ['류명숙', '1991-10-17', '033-372-7015', datetime.datetime(2024, 9, 5, 14, 5, 3)], ['김영자', '1990-04-16', '055-135-9384', datetime.datetime(2025, 1, 18, 19, 34, 50)], ['전성현', '1976-07-01', '051-022-8531', datetime.datetime(2024, 9, 8, 4, 27, 31)], ['장상철', '1973-04-15', '064-718-5733', datetime.datetime(2025, 12, 24, 22, 48, 47)], ['김은영', '1985-10-19', '033-803-9197', datetime.datetime(2026, 5, 4, 7, 15, 9)], ['전채원', '1959-03-29', '041-787-9569', datetime.datetime(2025, 11, 22, 2, 11, 25)], ['김수민', '1964-04-26', '054-165-3432', datetime.datetime(2025, 7, 18, 21, 10, 51)], ['김민석', '1962-06-30', '02-1345-1828', datetime.datetime(2025, 3, 2, 14, 57, 25)], ['김종수', '1958-09-03', '064-762-1720', datetime.datetime(2026, 7, 17, 21, 8, 33)], ['김경자', '2003-12-25', '051-045-0336', datetime.datetime(2025, ...

# %%
sql = "insert into maru_member(name,birth,phone,joined_at) values(:1, :2, :3, :4)"

with oracledb.connect(user="python_user",password=password,dsn="localhost/xe") as conn:
    with conn.cursor() as cursor:
        cursor.executemany(sql,data)
        conn.commit()
